# %%
import pandas as pd
import numpy as np

# %%
df_train = pd.read_csv(r'C:\Users\Ben Wong\Desktop\Venturenix Lab\Data Collection\Titanic\train.csv')
df_test = pd.read_csv(r'C:\Users\Ben Wong\Desktop\Venturenix Lab\Data Collection\Titanic\test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_train.groupby(['Embarked']).mean()
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C          445.357143  0.553571  1.886905  30.814769  0.386905  0.363095
# Q          417.896104  0.389610  2.909091  28.089286  0.428571  0.168831
# S          449.527950  0.336957  2.350932  29.445397  0.571429  0.413043
#
#                Fare
# Embarked
# C         59.954144
# Q         13.276030
# S         27.079812

# %%
df_train.groupby(['Pclass']).mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
c
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
df_train.groupby(['Sex','Embarked']).mean()
# Out:
#                  PassengerId  Survived    Pclass        Age     SibSp  \
# Sex    Embarked
# female C          437.315068  0.876712  1.726027  28.344262  0.547945
#        Q          374.138889  0.750000  2.888889  24.291667  0.222222
#        S          438.709360  0.689655  2.197044  27.771505  0.837438
# male   C          451.536842  0.305263  2.010526  32.998841  0.263158
#        Q          456.317073  0.073171  2.926829  30.937500  0.609756
#        S          454.507937  0.174603  2.421769  30.291440  0.448980
#
#                     Parch       Fare
# Sex    Embarked
# female C         0.493151  75.169805
#        Q         0.222222  12.634958
#        S         0.788177  38.740929
# male   C         0.263158  48.262109
#        Q         0.121951  13.838922
#        S         0.240363  21.711996

# %%
df_train['Survived'].mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# age: 0 - 9
# age: 10 - 19
#
# extract first character in Cabin
#
# one hot eoncoding
